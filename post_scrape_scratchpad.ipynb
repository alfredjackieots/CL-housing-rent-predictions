# %% [markdown]
# # Scrape individual posts for amentities

# %%
from bs4 import BeautifulSoup
import requests

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib as plt

# %%
from scrape_craigslist import get_listing_details, get_page_listings, clpage_to_df

# %% [markdown]
# ## Getting some URLs to test a few posts

# %%
# PDX Housing/Apartment Search Page
url = 'https://portland.craigslist.org/search/mlt/apa?s=120&availabilityMode=0&bundleDuplicates=1'

response = requests.get(url)
    
if response.status_code == 200:
    page = response.text

    # Create soup object from URL
    soup = BeautifulSoup(page, 'html.parser')
    
    # Create DF
    df = clpage_to_df(soup)
# Out:
# Scrape Complete!
# Number of Postings Scraped: 124

# %%
df.head()
# Out:
#      date                                              title  \
# 0  Sep 30  Penthouse, Full size refrigerator with ice mak...
# 1  Sep 30  How Does 1 Month Free Sound?! Snag This 1 BR w...
# 2  Sep 30    1 bedroom available now! Rent before it's gone!
# 3  Sep 30  Fall In Love in w/ This Corner 1 bedroom Home ...
# 4  Sep 30  The Emery, The ideal space to balance life, wo...
#
#                                                 link  price brs    sqft  \
# 0  https://portland.craigslist.org/mlt/apa/d/port...   2287   2  1185.0
# 1  https://portland.craigslist.org/mlt/apa/d/port...   1459   1     NaN
# 2  https://portland.craigslist.org/mlt/apa/d/port...   1420   1   765.0
# 3  https://portland.craigslist.org/mlt/apa/d/port...   1785   1   823.0
# 4  https://portland.craigslist.org/mlt/apa/d/port...   1795   2   718.0
#
#                                               hood
# 0                             1030 SW Jefferson St
# 1                                              NaN
# 2                             910 N. Harbour Drive
# 3  Slabtown, Alphabet District, Pearl, NW Portland
# 4                        Portland South Waterfront

# %% [markdown]
# ## Function to scrape URL listings for amenities details

# %%
def get_post_amenities(url_list):
    '''
    Function to scrape a list of Craigslist URLs for bathroom & amenities details. 
    Returns bathroom_list for bathrooms
    Returns amenties_list for amenities 
    '''
    
    bathrooms_list = []
    amenities_list = []
    
    index = 0
    
    for url in url_list:
        
        response = requests.get(url)
        page = response.text
        soup = BeautifulSoup(page, 'html.parser')
        
        
        # Each
        # Test how many groups there are: 
        
        # If 2 groups
        
        if len(soup.find_all('p', class_='attrgroup')) > 1:
    
            group1 = soup.find_all('p', class_='attrgroup')[0].text.split('\n')
            item_list1 = [item for item in group1 if item != '']
            
            # Check to see if first grouping contains number of bathrooms
            
            if item_list1[0][-2:] == 'Ba':
                brba = item_list1[0].split(' / ')
                bath = brba[-1]
            
            # if not bathrooms, then NaN and move on
            else:
                bath = np.nan
    
            # Second group should contain amenities - append raw list to amentities list
            
            group2 = soup.find_all('p', class_='attrgroup')[1].text.split('\n')
            amenities = [item for item in group2 if item != '']
        
        # If only 1 group 
        
        elif len(soup.find_all('p', class_='attrgroup')) == 1:
            
            items = soup.find_all('p', class_='attrgroup')[0].text.split('\n')
            item_list = [item for item in group1 if item != '']
            
            # Check to see if that group contains number of bathrooms
            if item_list[0][-2:] == 'Ba':
                brba = item_list1[0].split(' / ')
                bath = brba[-1]
            
            # otherwise, we just have amenities
            else:
                amenities = item_list
        
        # If no details on post page, fill with NaN
        else:
            bath = np.nan
            amenities = np.nan
        
        print("Index: ", index)      # Comment all this out later
        print("Baths: ", bath)
        print("Amens: ", amenities)
        print("")
        
        bathrooms_list.append(bath)
        amenities_list.append(amenities)

        index += 1
        
    print("Number of Posts Scraped: ", index)        
    return bathrooms_list, amenities_list

# %%
urls = list(df.link)

post_details = get_post_amenities(urls)
# Out:
# Index:  0
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  1
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  2
# Baths:  1Ba
# Amens:  ['open house dates', 'thursday 2020-10-01', 'friday 2020-10-02']
#
# Index:  3
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  4
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  5
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  6
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  7
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  8
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  9
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  10
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking', 'wheelchair accessible']
#
# Index:  11
# Baths:  1Ba
# Amens:  ['application fee details: No App Fee!', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'off-street parking']
#
# Index:  12
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'laundry on site', 'off-street parking']
#
# Index:  13
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  14
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  15
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'carport']
#
# Index:  16
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  17
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  18
# Baths:  1Ba
# Amens:  ['house', 'w/d hookups', 'off-street parking']
#
# Index:  19
# Baths:  2Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  20
# Baths:  2Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  21
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  22
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  23
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment']
#
# Index:  24
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  25
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  26
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  27
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment']
#
# Index:  28
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment']
#
# Index:  29
# Baths:  2Ba
# Amens:  ['wednesday 2020-09-30']
#
# Index:  30
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  31
# Baths:  2Ba
# Amens:  ['application fee details: 40.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  32
# Baths:  2.5Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  33
# Baths:  nan
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  34
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'in-law', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  35
# Baths:  0Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'off-street parking']
#
# Index:  36
# Baths:  1.5Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  37
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'apartment']
#
# Index:  38
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'apartment']
#
# Index:  39
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'apartment']
#
# Index:  40
# Baths:  1Ba
# Amens:  ['EV charging', 'application fee details: 13.00 for Credit, Background, and Rental Check', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  41
# Baths:  2Ba
# Amens:  ['open house dates', 'wednesday 2020-09-30', 'thursday 2020-10-01', 'friday 2020-10-02']
#
# Index:  42
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  43
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  44
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  45
# Baths:  1Ba
# Amens:  ['apartment', 'w/d in unit', 'attached garage']
#
# Index:  46
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'wheelchair accessible']
#
# Index:  47
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  48
# Baths:  2Ba
# Amens:  ['application fee details: $45 application fee pays for the screening that determines your deposit amount.', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  49
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  50
# Baths:  1Ba
# Amens:  ['EV charging', 'application fee details: $40 per adult, in certified funds only', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  51
# Baths:  1Ba
# Amens:  ['EV charging', 'application fee details: $40 per adult, in certified funds only', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'no smoking', 'off-street parking']
#
# Index:  52
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  53
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  54
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  55
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  56
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  57
# Baths:  2Ba
# Amens:  ['application fee details: 50.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'detached garage', 'wheelchair accessible']
#
# Index:  58
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'laundry in bldg', 'no smoking', 'street parking']
# Index:  59
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  60
# Baths:  2Ba
# Amens:  ['application fee details: 45.00 per adult applicant', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  61
# Baths:  2Ba
# Amens:  ['application fee details: 45.00 per adult applicant', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  62
# Baths:  2Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking']
#
# Index:  63
# Baths:  2Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'wheelchair accessible']
#
# Index:  64
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'flat', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  65
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 Screening Fee', 'cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'no smoking']
#
# Index:  66
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 Screening Fee', 'cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'apartment', 'laundry on site', 'no smoking', 'street parking']
#
# Index:  67
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 Screening Fee', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  68
# Baths:  1Ba
# Amens:  ['application fee details: 45.00 screening fee', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  69
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 Screening Fee', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'street parking']
#
# Index:  70
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  71
# Baths:  1Ba
# Amens:  ['apartment']
#
# Index:  72
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'duplex', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  73
# Baths:  1Ba
# Amens:  ['application fee details: $22(per applicant) charged upon approval', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  74
# Baths:  1Ba
# Amens:  ['furnished', 'condo', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  75
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  76
# Baths:  2.5Ba
# Amens:  ['application fee details: $45: credit, rental, and criminal', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  77
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'house', 'w/d hookups', 'no smoking', 'off-street parking']
#
# Index:  78
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  79
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'condo', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  80
# Baths:  1Ba
# Amens:  ['apartment', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  81
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'off-street parking']
#
# Index:  82
# Baths:  2.5Ba
# Amens:  ['house', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  83
# Baths:  1Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  84
# Baths:  1Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  85
# Baths:  1Ba
# Amens:  ['apartment', 'laundry on site', 'no smoking', 'off-street parking']
#
# Index:  86
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'street parking', 'wheelchair accessible']
#
# Index:  87
# Baths:  2Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  88
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  89
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  90
# Baths:  2.5Ba
# Amens:  ['application fee details: $45.00 for credit, criminal, and rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'townhouse', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  91
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  92
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  93
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  94
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  95
# Baths:  1.5Ba
# Amens:  ['open house dates', 'wednesday 2020-09-30', 'thursday 2020-10-01', 'friday 2020-10-02']
#
# Index:  96
# Baths:  2Ba
# Amens:  ['house', 'w/d hookups', 'off-street parking']
#
# Index:  97
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 credit, criminal, and rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  98
# Baths:  1Ba
# Amens:  ['application fee details: $45; credit, criminal, and rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  99
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 credit, criminal, and rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  100
# Baths:  1Ba
# Amens:  ['application fee details: $45; credit, criminal, and rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  101
# Baths:  1Ba
# Amens:  ['application fee details: $45.00; credit, criminal, & rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  102
# Baths:  1Ba
# Amens:  ['application fee details: $45.00 credit, criminal, and rental histories', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  103
# Baths:  2.5Ba
# Amens:  ['application fee details: $45: credit, rental, and criminal', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  104
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment']
#
# Index:  105
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  106
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  107
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'condo', 'w/d in unit', 'attached garage']
#
# Index:  108
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  109
# Baths:  3Ba
# Amens:  ['apartment', 'w/d hookups', 'no smoking']
#
# Index:  110
# Baths:  1Ba
# Amens:  ['apartment', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  111
# Baths:  1Ba
# Amens:  ['application fee details: $50', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport', 'wheelchair accessible']
#
# Index:  112
# Baths:  1Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  113
# Baths:  1Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking']
#
# Index:  114
# Baths:  2Ba
# Amens:  ['townhouse', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  115
# Baths:  1Ba
# Amens:  ['apartment', 'laundry on site', 'no smoking', 'off-street parking']
# Index:  116
# Baths:  1Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  117
# Baths:  1Ba
# Amens:  ['apartment', 'w/d in unit', 'no smoking']
#
# Index:  118
# Baths:  1Ba
# Amens:  ['condo', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  119
# Baths:  1.5Ba
# Amens:  ['apartment', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  120
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  121
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  122
# Baths:  1Ba
# Amens:  ['application fee details: $40', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d hookups', 'no smoking']
#
# Index:  123
# Baths:  2Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Number of Posts Scraped:  124

# %%
len(urls)
# Out:
# 124

# %%
links = urls

index = 0

ones = []
twos = []
threes = []

for url in urls:
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, 'html.parser')
    
    items = soup.find_all('p', class_='attrgroup')
    groupings = len(items)
    if groupings == 1:
        ones.append((index, groupings, list(items)))
    elif groupings == 2:
        twos.append((index, groupings, list(items)))
    else:
        threes.append((index, groupings, list(items)))
    
    index += 1

# %% [markdown]
# threes have **"OPEN HOUSE"**

# %%
print("Number of 3-groups: ", len(threes))

for group in threes:
    print("index: ", group[0])
    print(group[2])
    print("")
# Out:
# Number of 3-groups:  4
# index:  2
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>1BR</b> / <b>1Ba</b></span>
# <span class="shared-line-bubble"><b>765</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-09-30" data-today_msg="available now">available sep 30</span>
# </p>, <p class="attrgroup">
# <b>open house dates</b>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-01">thursday 2020-10-01</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-02">friday 2020-10-02</a>
# </span>
# </p>, <p class="attrgroup">
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>w/d in unit</span>
# <br/>
# <span>no smoking</span>
# <br/>
# <span>carport</span>
# <br/>
# </p>]
#
# index:  29
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>2BR</b> / <b>2Ba</b></span>
# <span class="shared-line-bubble"><b>966</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-09-30" data-today_msg="available now">available sep 30</span>
# </p>, <p class="attrgroup">
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-09-30">wednesday 2020-09-30</a>
# </span>
# </p>, <p class="attrgroup">
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>w/d in unit</span>
# <br/>
# <span>detached garage</span>
# <br/>
# </p>]
#
# index:  41
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>3BR</b> / <b>2Ba</b></span>
# <span class="shared-line-bubble"><b>1113</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-09-30" data-today_msg="available now">available sep 30</span>
# </p>, <p class="attrgroup">
# <b>open house dates</b>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-09-30">wednesday 2020-09-30</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-01">thursday 2020-10-01</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-02">friday 2020-10-02</a>
# </span>
# </p>, <p class="attrgroup">
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>w/d in unit</span>
# <br/>
# <span>no smoking</span>
# <br/>
# </p>]
#
# index:  95
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>2BR</b> / <b>1.5Ba</b></span>
# <span class="shared-line-bubble"><b>957</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-10-30" data-today_msg="available now">available oct 30</span>
# </p>, <p class="attrgroup">
# <b>open house dates</b>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-09-30">wednesday 2020-09-30</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-01">thursday 2020-10-01</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-02">friday 2020-10-02</a>
# </span>
# </p>, <p class="attrgroup">
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>w/d in unit</span>
# <br/>
# <span>no smoking</span>
# <br/>
# </p>]
