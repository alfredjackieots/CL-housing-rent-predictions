# %% [markdown]
# # Scrape individual posts for amentities

# %%
from bs4 import BeautifulSoup
import requests

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib as plt

# %%
from scrape_craigslist import get_listing_details, get_page_listings, clpage_to_df

# %% [markdown]
# ## Getting some URLs to test a few posts

# %%
# PDX Housing/Apartment Search Page
url = 'https://portland.craigslist.org/search/mlt/apa?s=120&availabilityMode=0&bundleDuplicates=1'

response = requests.get(url)
    
if response.status_code == 200:
    page = response.text

    # Create soup object from URL
    soup = BeautifulSoup(page, 'html.parser')
    
    # Create DF
    df = clpage_to_df(soup)
# Out:
# Scrape Complete!
# Number of Postings Scraped: 121

# %%
df.head()
# Out:
#      date                                              title  \
# 0  Sep 30        Immaculate 2 bed 2 bath w/ an open concept!
# 1  Sep 30            Upscale condo in the heart of the Pearl
# 2  Sep 30  2 Bedroom Apartment Available with Washer/Drye...
# 3  Sep 30     Classic 1 Bedroom Downtown Apartment *Special*
# 4  Sep 30  Soak In The Amenities! Fitness Room, Spa, Saun...
#
#                                                 link  price  brs    sqft  \
# 0  https://portland.craigslist.org/mlt/apa/d/lake...   1792    2  1176.0
# 1  https://portland.craigslist.org/mlt/apa/d/port...   1725  NaN   780.0
# 2  https://portland.craigslist.org/mlt/apa/d/port...   1750    2   887.0
# 3  https://portland.craigslist.org/mlt/apa/d/port...    999    1   624.0
# 4  https://portland.craigslist.org/mlt/apa/d/port...   1077  NaN     NaN
#
#                                   hood
# 0  1 Jefferson Parkway Lake Oswego, OR
# 1                                Pearl
# 2                             Portland
# 3                  221 NW Fifth Avenue
# 4                                  NaN

# %% [markdown]
# ## Function to scrape URL listings for amenities details

# %%
def get_post_amenities(url_list):
    '''
    Function to scrape a list of Craigslist URLs for bathroom & amenities details. 
    Returns bathroom_list for bathrooms
    Returns amenties_list for amenities 
    '''
    
    bathrooms_list = []
    amenities_list = []
    
    index = 0
    
    for url in url_list:
        
        response = requests.get(url)
        page = response.text
        soup = BeautifulSoup(page, 'html.parser')
        
        
        # Each
        # Test how many groups there are: 
        
        # If 2 groups
        
        if len(soup.find_all('p', class_='attrgroup')) > 1:
    
            group1 = soup.find_all('p', class_='attrgroup')[0].text.split('\n')
            item_list1 = [item for item in group1 if item != '']
            
            # Check to see if first grouping contains number of bathrooms
            
            if item_list1[0][-2:] == 'Ba':
                brba = item_list1[0].split(' / ')
                bath = brba[-1]
            
            # if not bathrooms, then NaN and move on
            else:
                bath = np.nan
    
            # Grouping 2 will be either Open House dates or Amenities:
            # If only 2 groups, then return amenities
            # If there are 3 groups, skip group 2 (Open House dates) and return amenities
            
            if len(soup.find_all('p', class_='attrgroup')) == 2:
            
                group2 = soup.find_all('p', class_='attrgroup')[1].text.split('\n')
                amenities = [item for item in group2 if item != '']
                
            else:
                group2 = soup.find_all('p', class_='attrgroup')[2].text.split('\n')
                amenities = [item for item in group2 if item != '']         
        
        # If only 1 group 
        
        elif len(soup.find_all('p', class_='attrgroup')) == 1:
            
            items = soup.find_all('p', class_='attrgroup')[0].text.split('\n')
            item_list = [item for item in group1 if item != '']
            
            # Check to see if that group contains number of bathrooms
            if item_list[0][-2:] == 'Ba':
                brba = item_list1[0].split(' / ')
                bath = brba[-1]
            
            # otherwise, we just have amenities
            else:
                amenities = item_list
        
        # If no details on post page, fill with NaN
        else:
            bath = np.nan
            amenities = np.nan
        
        print("Index: ", index)      # Comment all this out later
        print("Baths: ", bath)
        print("Amens: ", amenities)
        print("")
        
        bathrooms_list.append(bath)
        amenities_list.append(amenities)

        index += 1
        
    print("Number of Posts Scraped: ", index)        
    return bathrooms_list, amenities_list

# %%
urls = list(df.link)

post_details = get_post_amenities(urls)
# Out:
# Index:  0
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit']
#
# Index:  1
# Baths:  1Ba
# Amens:  ['loft', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  2
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  3
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  4
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  5
# Baths:  2Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  6
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  7
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  8
# Baths:  1Ba
# Amens:  ['application fee details: $40 App Fee', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  9
# Baths:  2Ba
# Amens:  ['application fee details: $45 application fee pays for the screening that determines your deposit amount.', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  10
# Baths:  1Ba
# Amens:  ['application fee details: $45 per adult applicant', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'off-street parking']
#
# Index:  11
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  12
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  13
# Baths:  nan
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'detached garage']
#
# Index:  14
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  15
# Baths:  1Ba
# Amens:  ['application fee details: $45 Application fee - credit, criminal and rental screening', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  16
# Baths:  1Ba
# Amens:  ['application fee details: $40 Application Fee, Per Adult Applicant (non-refundable)', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  17
# Baths:  1Ba
# Amens:  ['application fee details: $45 Application fee - credit, criminal and rental screening', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  18
# Baths:  2Ba
# Amens:  ['apartment']
#
# Index:  19
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  20
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  21
# Baths:  nan
# Amens:  ['furnished', 'apartment', 'no smoking']
#
# Index:  22
# Baths:  1Ba
# Amens:  ['application fee details: 47.00 pp', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking']
#
# Index:  23
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  24
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  25
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment']
#
# Index:  26
# Baths:  nan
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit']
#
# Index:  27
# Baths:  2Ba
# Amens:  ['apartment']
#
# Index:  28
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  29
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking']
#
# Index:  30
# Baths:  1Ba
# Amens:  ['house', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  31
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'apartment', 'laundry on site', 'off-street parking']
#
# Index:  32
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'detached garage', 'wheelchair accessible']
#
# Index:  33
# Baths:  1Ba
# Amens:  ['application fee details: $45 App Fee per Adult', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  34
# Baths:  1.5Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'house', 'w/d hookups', 'no smoking', 'attached garage']
#
# Index:  35
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit']
#
# Index:  36
# Baths:  1Ba
# Amens:  ['application fee details: 47.00 pp', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking']
#
# Index:  37
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  38
# Baths:  1Ba
# Amens:  ['application fee details: 47.00 pp', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'attached garage']
#
# Index:  39
# Baths:  1Ba
# Amens:  ['application fee details: 47.00 pp', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking']
#
# Index:  40
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'off-street parking']
#
# Index:  41
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  42
# Baths:  1Ba
# Amens:  ['application fee details: 47.00 pp', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking']
#
# Index:  43
# Baths:  1Ba
# Amens:  ['application fee details: 47.00 pp', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking']
#
# Index:  44
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'off-street parking']
#
# Index:  45
# Baths:  nan
# Amens:  ['furnished', 'apartment', 'no smoking']
#
# Index:  46
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  47
# Baths:  nan
# Amens:  ['furnished', 'apartment', 'no smoking']
#
# Index:  48
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'off-street parking']
#
# Index:  49
# Baths:  nan
# Amens:  ['furnished', 'apartment', 'no smoking']
#
# Index:  50
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  51
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'off-street parking']
#
# Index:  52
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  53
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'w/d in unit', 'no smoking']
#
# Index:  54
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  55
# Baths:  1.5Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  56
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'off-street parking']
#
# Index:  57
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'off-street parking']
#
# Index:  58
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg']
# Index:  59
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'off-street parking']
#
# Index:  60
# Baths:  1Ba
# Amens:  ['apartment']
#
# Index:  61
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  62
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  63
# Baths:  1Ba
# Amens:  ['apartment', 'laundry on site', 'no smoking', 'no parking']
#
# Index:  64
# Baths:  1Ba
# Amens:  ['apartment', 'laundry on site', 'no smoking', 'no parking']
#
# Index:  65
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit']
#
# Index:  66
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  67
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  68
# Baths:  1Ba
# Amens:  ['application fee details: 45', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  69
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'carport']
#
# Index:  70
# Baths:  1Ba
# Amens:  ['application fee details: There is an application/screening fee', 'dogs are OK - wooof', 'duplex', 'w/d hookups', 'attached garage']
#
# Index:  71
# Baths:  2Ba
# Amens:  ['EV charging', 'application fee details: $45 Application Fee', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  72
# Baths:  1Ba
# Amens:  ['EV charging', 'application fee details: $45 application fee - credit, criminal and rental screening', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  73
# Baths:  1Ba
# Amens:  ['EV charging', 'application fee details: $45 application fee - credit, criminal and rental screening', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  74
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  75
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  76
# Baths:  nan
# Amens:  ['house', 'no smoking']
#
# Index:  77
# Baths:  2.5Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'house', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  78
# Baths:  1Ba
# Amens:  ['application fee details: $50 per person', 'cats are OK - purrr', 'apartment', 'w/d in unit', 'no smoking', 'street parking']
#
# Index:  79
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  80
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking']
#
# Index:  81
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  82
# Baths:  1Ba
# Amens:  ['EV charging', 'application fee details: $40 per adult, in certified funds only', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  83
# Baths:  2Ba
# Amens:  ['application fee details: $45 application fee for background screening and credit check', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  84
# Baths:  1Ba
# Amens:  ['application fee details: 50.00', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  85
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  86
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'apartment', 'w/d in unit', 'no smoking']
#
# Index:  87
# Baths:  1Ba
# Amens:  ['application fee details: 45', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  88
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  89
# Baths:  1.5Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'townhouse', 'w/d in unit', 'no smoking', 'detached garage']
#
# Index:  90
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  91
# Baths:  nan
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  92
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  93
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  94
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  95
# Baths:  1Ba
# Amens:  ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage']
#
# Index:  96
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport']
#
# Index:  97
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  98
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  99
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  100
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  101
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  102
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  103
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  104
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking', 'wheelchair accessible']
#
# Index:  105
# Baths:  1Ba
# Amens:  ['application fee details: No App Fee!', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'off-street parking']
#
# Index:  106
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'laundry on site', 'off-street parking']
#
# Index:  107
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'off-street parking']
#
# Index:  108
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport']
#
# Index:  109
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'carport']
#
# Index:  110
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'off-street parking', 'wheelchair accessible']
#
# Index:  111
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  112
# Baths:  1Ba
# Amens:  ['house', 'w/d hookups', 'off-street parking']
#
# Index:  113
# Baths:  2Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
# Index:  114
# Baths:  2Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking']
#
# Index:  115
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  116
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'wheelchair accessible']
#
# Index:  117
# Baths:  1Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment']
#
# Index:  118
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  119
# Baths:  2Ba
# Amens:  ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Index:  120
# Baths:  1Ba
# Amens:  ['application fee details: 45.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking']
#
# Number of Posts Scraped:  121

# %%
len(urls)
# Out:
# 121

# %%
links = urls

index = 0

ones = []
twos = []
threes = []

for url in urls:
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, 'html.parser')
    
    items = soup.find_all('p', class_='attrgroup')
    groupings = len(items)
    if groupings == 1:
        ones.append((index, groupings, list(items)))
    elif groupings == 2:
        twos.append((index, groupings, list(items)))
    else:
        threes.append((index, groupings, list(items)))
    
    index += 1

# %% [markdown]
# threes have **"OPEN HOUSE"**

# %%
print("Number of 3-groups: ", len(threes))



for group in threes:
    print("index: ", group[0])
    print(group[2])
    print("")
# Out:
# Number of 3-groups:  3
# index:  5
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>2BR</b> / <b>2Ba</b></span>
# <span class="shared-line-bubble"><b>1208</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-09-30" data-today_msg="available now">available sep 30</span>
# </p>, <p class="attrgroup">
# <b>open house dates</b>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-01">thursday 2020-10-01</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-02">friday 2020-10-02</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-03">saturday 2020-10-03</a>
# </span>
# </p>, <p class="attrgroup">
# <span>EV charging</span>
# <br/>
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>w/d in unit</span>
# <br/>
# <span>no smoking</span>
# <br/>
# <span>attached garage</span>
# <br/>
# <span>wheelchair accessible</span>
# <br/>
# </p>]
#
# index:  69
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>2BR</b> / <b>1Ba</b></span>
# <span class="shared-line-bubble"><b>792</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-09-30" data-today_msg="available now">available sep 30</span>
# </p>, <p class="attrgroup">
# <b>open house dates</b>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-09-30">wednesday 2020-09-30</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-01">thursday 2020-10-01</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-02">friday 2020-10-02</a>
# </span>
# </p>, <p class="attrgroup">
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>laundry on site</span>
# <br/>
# <span>no smoking</span>
# <br/>
# <span>carport</span>
# <br/>
# </p>]
#
# index:  96
# [<p class="attrgroup">
# <span class="shared-line-bubble"><b>1BR</b> / <b>1Ba</b></span>
# <span class="shared-line-bubble"><b>765</b>ft<sup>2</sup></span>
# <span class="housing_movein_now property_date shared-line-bubble" data-date="2020-09-30" data-today_msg="available now">available sep 30</span>
# </p>, <p class="attrgroup">
# <b>open house dates</b>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-01">thursday 2020-10-01</a>
# </span>
# <br/>
# <span class="otherpostings">
# <a href="/search/apa?sale_date=2020-10-02">friday 2020-10-02</a>
# </span>
# </p>, <p class="attrgroup">
# <span>cats are OK - purrr</span>
# <br/>
# <span>dogs are OK - wooof</span>
# <br/>
# <span>apartment</span>
# <br/>
# <span>w/d in unit</span>
# <br/>
# <span>no smoking</span>
# <br/>
# <span>carport</span>
# <br/>
# </p>]
